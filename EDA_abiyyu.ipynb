# %% [markdown]
# <a href="https://colab.research.google.com/github/mansorabi324/7-Abiyyu-Derryl/blob/main/EDA_abiyyu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("EDA")
# Out:
# EDA
